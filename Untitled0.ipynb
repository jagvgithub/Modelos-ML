# %% [markdown]
# <a href="https://colab.research.google.com/github/jagvgithub/Modelos-ML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Crear un DataFrame con valores aleatorios
np.random.seed(42)
data = np.random.randn(100, 5)  # 100 filas y 5 columnas de datos aleatorios
df = pd.DataFrame(data, columns=['Columna1', 'Columna2', 'Columna3', 'Columna4', 'Columna5'])

# Agregar una columna de validación con valores aleatorios de 0 y 1
df['Validacion'] = np.random.randint(2, size=100)

# Mostrar el DataFrame
print(df)
# Out:
#     Columna1  Columna2  Columna3  Columna4  Columna5  Validacion
# 0   0.496714 -0.138264  0.647689  1.523030 -0.234153           1
# 1  -0.234137  1.579213  0.767435 -0.469474  0.542560           1
# 2  -0.463418 -0.465730  0.241962 -1.913280 -1.724918           1
# 3  -0.562288 -1.012831  0.314247 -0.908024 -1.412304           0
# 4   1.465649 -0.225776  0.067528 -1.424748 -0.544383           1
# ..       ...       ...       ...       ...       ...         ...
# 95 -0.249036  0.576557  0.311250  3.078881  1.119575           1
# 96 -0.127918 -0.955540 -1.606446  0.203464 -0.756351           0
# 97 -1.422254 -0.646573 -1.081548  1.687142  0.881640           1
# 98 -0.007973  1.479944  0.077368 -0.861284  1.523124           1
# 99  0.538910 -1.037246 -0.190339 -0.875618 -1.382800           1
#
# [100 rows x 6 columns]

# %%
# !pip install pycaret
from pycaret.datasets import get_data
dataset = get_data('credit')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 74.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 74.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 46.0 MB/s eta 0:00:00
# ...

# %%
dataset.shape
# Out:
# (24000, 24)

# %%
data=dataset.sample(frac=0.75,random_state=786).reset_index(drop=True) # entrenamitno
data_unusen =dataset.drop(data.index).reset_index(drop=True) # testeo

# %%
print(data.shape,data_unusen.shape)
# Out:
# (18000, 24) (6000, 24)

# %%
from pycaret.classification import * # la data ya tiene una marcacion de  01

exp_clf101 = setup(data=data,target='default',session_id=10001)  # RESUMEN DE LA VARIABLES
# Out:
# <style type="text/css">
# #T_5fdae_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5fdae" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fdae_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5fdae_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fdae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fdae_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5fdae_row0_col1" class="data row0 col1" >10001</td>
#     </tr>
#     <tr>
#       <th id="T_5fdae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5fdae_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5fdae_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_5fdae_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_254ed th {
#   text-align: left;
# }
# ...

# %%
git remote add origin https://github.com/jagvgithub/Modelos-ML.git
git branch -M main
git push -u origin main
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-10-0520ace3404f>, line 1)
